# %%
import pandas as pd

import seaborn as sns

# %%
busia_df = pd.read_csv('BusiaTravel.csv')
busia_df.drop(columns=['Year_text', 'Results_Status','OBJECTID'],inplace=True)

busia_df.tail()
# Out:
#     Travel_Route                    Year  Visitors_on_Holiday  \
# 203   Departures  12/31/2013 12:00:00 AM               323300
# 204   Departures  12/31/1991 12:00:00 AM               142800
# 205   Departures  12/31/1992 12:00:00 AM                61800
# 206   Departures  12/31/1993 12:00:00 AM               113600
# 207   Departures  12/31/1994 12:00:00 AM               123400
#
#      Visitors_on_Business  Visitors_in_Transit  Other_Visitors Quater
# 203                 53000                23200           32600     Q4
# 204                 16400                12600            1100     Q4
# 205                 16300                 9400            1300     Q4
# 206                 30000                17300            2400     Q4
# 207                 32600                18800            2600     Q4

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Types Of Features
# * Categorical
#   * Nominal
#   * Ordinal
#   * Interval
#   * Binary
# * Numerical
# * Other Types
#   * Timeseries
#   * Audio
#   * Video
#   * Text

# %% [markdown]
# ## Missing Data
#
# Ways of dealing with missing values
#
# 1. Removing them altogether
# 2. Fill in using (0, median, minimum, maximum, any other values)

# %% [markdown]
# ##  Outliers
# Samples that veer too off from other data. They may be due to human error, corrupt data,
#
# <img src="Images/Outliers.jpg">
#
# ## Why we need to deal with outliers
# * Might strongly influence model (in a bad way)
# ### Detection
#
# * Using standard deviation
# * Using clustering algorithms
#
#
# **Be careful when removing outliers, it possible the data was poorly sampled**

# %% [markdown]
# ### Correlation
#
# Measure of interdependence of variable quantities.
#
# <img src="Images/correlation.png">

# %% [markdown]
# Importance of correlation
# * Detect negative correlated data
# * Detect multicollinearity (Structural and Data)
#
# **Find a sweet spot**

# %%
corr = busia_df.corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %% [markdown]
# ## Normalizing
#
# This is the process of transforming data to a common scale because some algorithms treating data differently based on magnitude

# %%
from sklearn import preprocessing
busia_df_normalized = busia_df
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(busia_df[['Visitors_in_Transit','Visitors_on_Holiday','Visitors_on_Business','Other_Visitors']])
busia_df_normalized[['Visitors_in_Transit','Visitors_on_Holiday','Visitors_on_Business','Other_Visitors']] = np_scaled
busia_df_normalized
# Out:
# /home/sylvia/face/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#     Travel_Route                    Year  Visitors_on_Holiday  \
# 0       Arrivals  03/31/2005 12:00:00 AM             0.069830
# 1       Arrivals  06/30/1991 12:00:00 AM             0.030163
# 2       Arrivals  09/30/1991 12:00:00 AM             0.053061
# 3       Arrivals  12/31/1991 12:00:00 AM             0.033262
# 4       Arrivals  03/31/1992 12:00:00 AM             0.032229
# 5       Arrivals  06/30/1992 12:00:00 AM             0.025618
# 6       Arrivals  09/30/1992 12:00:00 AM             0.051408
# 7       Arrivals  12/31/1992 12:00:00 AM             0.014531
# 8       Arrivals  03/31/1993 12:00:00 AM             0.002582
# 9       Arrivals  06/30/1993 12:00:00 AM             0.051649
# 10      Arrivals  09/30/1993 12:00:00 AM             0.050582
# 11      Arrivals  12/31/1993 12:00:00 AM             0.044143
# 12      Arrivals  03/31/1994 12:00:00 AM             0.028786
# 13      Arrivals  06/30/1994 12:00:00 AM             0.044969
# 14      Arrivals  09/30/1994 12:00:00 AM             0.043902
# 15      Arrivals  12/31/1994 12:00:00 AM             0.030990
# 16      Arrivals  03/31/1995 12:00:00 AM             0.052028
# 17      Arrivals  06/30/1995 12:00:00 AM             0.041423
# 18      Arrivals  09/30/1995 12:00:00 AM             0.047449
# 19      Arrivals  12/31/1995 12:00:00 AM             0.048172
# 20      Arrivals  03/31/1996 12:00:00 AM             0.052338
# 21      Arrivals  06/30/1996 12:00:00 AM             0.039081
# 22      Arrivals  09/30/1996 12:00:00 AM             0.051753
# 23      Arrivals  12/31/1996 12:00:00 AM             0.054335
# 24      Arrivals  03/31/1997 12:00:00 AM             0.059156
# 25      Arrivals  06/30/1997 12:00:00 AM             0.039460
# 26      Arrivals  09/30/1997 12:00:00 AM             0.051030
# 27      Arrivals  12/31/1997 12:00:00 AM             0.036774
# 28      Arrivals  03/31/1998 12:00:00 AM             0.045142
# 29      Arrivals  06/30/1998 12:00:00 AM             0.030232
# ..           ...                     ...                  ...
# 178   Departures  09/30/1997 12:00:00 AM             0.045968
# 179   Departures  12/31/2010 12:00:00 AM             0.085118
# 180   Departures  09/30/1998 12:00:00 AM             0.036120
# 181   Departures  03/31/2011 12:00:00 AM             0.074306
# 182   Departures  09/30/1999 12:00:00 AM             0.048619
# 183   Departures  06/30/2011 12:00:00 AM             0.049273
# 184   Departures  09/30/2000 12:00:00 AM             0.051408
# 185   Departures  09/30/2011 12:00:00 AM             0.089870
# 186   Departures  09/30/2001 12:00:00 AM             0.042318
# 187   Departures  12/31/2011 12:00:00 AM             0.086909
# 188   Departures  09/30/2002 12:00:00 AM             0.045555
# 189   Departures  03/31/2012 12:00:00 AM             0.075718
# 190   Departures  09/30/2003 12:00:00 AM             0.042043
# 191   Departures  06/30/2012 12:00:00 AM             0.053096
# 192   Departures  09/30/2004 12:00:00 AM             0.061118
# 193   Departures  09/30/2012 12:00:00 AM             0.081193
# 194   Departures  09/30/2005 12:00:00 AM             0.074892
# 195   Departures  12/31/2012 12:00:00 AM             0.078369
# 196   Departures  09/30/2006 12:00:00 AM             0.073376
# 197   Departures  03/31/2013 12:00:00 AM             0.069623
# 198   Departures  09/30/2007 12:00:00 AM             0.100131
# 199   Departures  06/30/2013 12:00:00 AM             0.049928
# 200   Departures  09/30/2008 12:00:00 AM             0.065319
# 201   Departures  09/30/2013 12:00:00 AM             0.070209
# 202   Departures  09/30/2009 12:00:00 AM             0.075821
# 203   Departures  12/31/2013 12:00:00 AM             0.090042
# 204   Departures  12/31/1991 12:00:00 AM             0.027891
# 205   Departures  12/31/1992 12:00:00 AM             0.000000
# 206   Departures  12/31/1993 12:00:00 AM             0.017836
# 207   Departures  12/31/1994 12:00:00 AM             0.021211
#
#      Visitors_on_Business  Visitors_in_Transit  Other_Visitors Quater
# 0                0.676332             0.044894        0.099521     Q1
# 1                0.002832             0.000000        0.005854     Q2
# 2                0.011598             0.021265        0.010378     Q3
# 3                0.007417             0.019428        0.020490     Q4
# 4                0.033176             0.037018        0.014103     Q1
# 5                0.017262             0.025203        0.015434     Q2
# 6                0.006473             0.009189        0.003459     Q3
# 7                0.012272             0.008401        0.003991     Q4
# 8                0.015779             0.018115        0.002395     Q1
# 9                0.012407             0.011814        0.000266     Q2
# 10               0.007417             0.019953        0.000532     Q3
# 11               0.017802             0.019428        0.000000     Q4
# 12               0.062441             0.059596        0.006386     Q1
# 13               0.009440             0.009451        0.000266     Q2
# 14               0.004990             0.017065        0.000532     Q3
# 15               0.010249             0.013127        0.000000     Q4
# 16               0.016723             0.022841        0.014902     Q1
# 17               0.011463             0.023103        0.012507     Q2
# 18               0.014295             0.023628        0.013837     Q3
# 19               0.014835             0.023366        0.014103     Q4
# 20               0.016858             0.018378        0.014902     Q1
# 21               0.010249             0.018115        0.012241     Q2
# 22               0.016588             0.031767        0.014902     Q3
# 23               0.017937             0.025729        0.015168     Q4
# 24               0.020229             0.023891        0.016232     Q1
# 25               0.010519             0.027304        0.012241     Q2
# 26               0.016183             0.040168        0.014635     Q3
# 27               0.012003             0.044894        0.012773     Q4
# 28               0.013351             0.076135        0.013305     Q1
# 29               0.005934             0.040693        0.010378     Q2
# ..                    ...                  ...             ...    ...
# 178              0.013621             0.039118        0.013571     Q3
# 179              0.042751             0.050932        0.077169     Q4
# 180              0.008766             0.049619        0.011442     Q3
# 181              0.057181             0.040168        0.096860     Q1
# 182              0.014160             0.063796        0.017030     Q3
# 183              0.051113             0.031767        0.084353     Q2
# 184              0.016318             0.069835        0.014369     Q3
# 185              0.022792             0.018115        0.124800     Q3
# 186              0.011868             0.085587        0.013039     Q3
# 187              0.057991             0.018378        0.088345     Q4
# 188              0.007957             0.084799        0.011176     Q3
# 189              0.053405             0.052770        0.077169     Q1
# 190              0.052461             0.149646        0.030335     Q3
# 191              0.052866             0.034917        0.097924     Q2
# 192              0.075927             0.109740        0.033528     Q3
# 193              0.042481             0.046994        0.132251     Q3
# 194              0.054349             0.037805        0.115753     Q3
# 195              0.044909             0.034917        0.075306     Q4
# 196              0.061227             0.058808        0.121341     Q3
# 197              0.050169             0.042793        0.089409     Q1
# 198              0.066487             0.073248        0.127461     Q3
# 199              0.057451             0.032029        0.070782     Q2
# 200              0.023466             0.033080        0.040713     Q3
# 201              0.035064             0.039643        0.117616     Q3
# 202              0.034525             0.070885        0.116551     Q3
# 203              0.051922             0.047519        0.086216     Q4
# 204              0.002562             0.019690        0.002395     Q4
# 205              0.002428             0.011289        0.002927     Q4
# 206              0.020904             0.032029        0.005854     Q4
# 207              0.024410             0.035967        0.006386     Q4
#
# [208 rows x 7 columns]

# %%
# %matplotlib inline
boxplot = busia_df.boxplot(column=['Visitors_on_Holiday','Visitors_on_Business','Visitors_in_Transit','Other_Visitors'])
